# %% [markdown]
# <a href="https://colab.research.google.com/github/kishore779/Pytorch_Programming/blob/main/Pytorch_00_programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pytorch Learning in Deep Learning----

# %%
# !pip install torch torchvision torchaudio

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Introduction to Pytorch
#
# ## Creating Tensors

# %%
scalar = torch.tensor(7)
scalar
# Out:
# tensor(7)

# %%
scalar.ndim
# Out:
# 0

# %%
scalar.item()
# Out:
# 7

# %%
vector = torch.tensor([7,9])
vector
# Out:
# tensor([7, 9])

# %%
vector.ndim
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([2])

# %%
MATRIX = torch.tensor([[7,8]
                       ,[8,9]])
MATRIX
# Out:
# tensor([[7, 8],
#         [8, 9]])

# %%
MATRIX.ndim
# Out:
# 2

# %%
MATRIX.shape
# Out:
# torch.Size([2, 2])

# %%
TENSORS = torch.tensor([[[2,3,4],
                        [3,4,5],
                        [6,7,8]]])
TENSORS
# Out:
# tensor([[[2, 3, 4],
#          [3, 4, 5],
#          [6, 7, 8]]])

# %%
TENSORS.ndim
# Out:
# 3

# %%
TENSORS.shape
# Out:
# torch.Size([1, 3, 3])

# %%
TENSORS1 = torch.tensor([[1,2],
                         [3,4],
                         [5,6]])
TENSORS1
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
TENSORS1.shape
# Out:
# torch.Size([3, 2])

# %%
TENSORS1[0]
# Out:
# tensor([1, 2])

# %% [markdown]
# `Radomized Tensor Creating`

# %%
random_tensor = torch.rand(1,5,5)
random_tensor
# Out:
# tensor([[[0.9090, 0.0636, 0.9962, 0.0333, 0.5842],
#          [0.0355, 0.6874, 0.1126, 0.7479, 0.2415],
#          [0.1115, 0.6788, 0.9833, 0.0143, 0.2252],
#          [0.4470, 0.4183, 0.7919, 0.4846, 0.4946],
#          [0.1940, 0.8109, 0.5809, 0.9092, 0.1973]]])

# %%
random_tensor.ndim
# Out:
# 2

# %%
#create a tensor with similar shape of the image

random_image_sizetensor = torch.rand(size=(224,224,3))
random_image_sizetensor.shape,random_image_sizetensor.ndim
# Out:
# (torch.Size([224, 224, 3]), 3)
